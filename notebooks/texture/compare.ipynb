# %%
import lightroot
import numpy as np
import pandas as pd
# %matplotlib inline

from skimage import io
leaf = io.imread("./leaf_sample.PNG",as_grey=True)
lightroot.io.plotimg(leaf)
root = io.imread("./root_sample.PNG", as_grey=True)
lightroot.io.plotimg(root)

# %%
lightroot.io.tiling(root,divs=5)

# %%
tile_of_root = lightroot.io.tile(root,2,2,5)
tile_of_root2 = lightroot.io.tile(root,2,3,5)
lightroot.io.plotimg(tile_of_root)
lightroot.io.plotimg(tile_of_root2)

# %%
lightroot.io.tiling(leaf,divs=5)

# %%
plt.imshow(tile_of_leaf)

# %%
plt.imshow(tile_of_root)

# %%
tile_of_leaf = lightroot.io.tile(leaf, 4,1,5)
tile_of_leaf2 = lightroot.io.tile(leaf, 3,1,5)
lightroot.io.plotimg(tile_of_leaf)
lightroot.io.plotimg(tile_of_leaf2)

# %% [markdown]
# # Compare Freq ad Phase components

# %% [markdown]
# # Compare Descriptors

# %%
#conmpare lbfs do this pairwaise for all tiles with content

def show_lbf(image, radius=6):
    from skimage.feature import local_binary_pattern
    METHOD = 'uniform'
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, METHOD)
    n_bins = int(lbp.max() + 1)
    hist, bin_edges = np.histogram(lbp, normed=True, bins=n_bins, range=(0, n_bins))
    import matplotlib.pyplot as plt
    plt.bar(bin_edges[:-1], hist, width = 1)
    plt.xlim(min(bin_edges), max(bin_edges))
    plt.show()   

def show_hog(image, orientations=8):
    from skimage.feature import hog
    from skimage import data, exposure

    f, hog_image = hog(image, orientations=orientations, pixels_per_cell=(16, 16),  cells_per_block=(1, 1), visualise=True )

    hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

    plt.imshow(hog_image_rescaled, cmap=plt.cm.gray)
    
    return f
    
#show_lbf(tile_of_root)
#show_lbf(tile_of_root2)
#show_lbf(tile_of_leaf)
#show_lbf(tile_of_leaf2)

#conmpare lbfs do this pairwaise for all tiles with content

def show_lbf(image, radius=6):
    from skimage.feature import local_binary_pattern
    METHOD = 'uniform'
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, METHOD)
    n_bins = int(lbp.max() + 1)
    hist, bin_edges = np.histogram(lbp, normed=True, bins=n_bins, range=(0, n_bins))
    import matplotlib.pyplot as plt
    plt.bar(bin_edges[:-1], hist, width = 1)
    plt.xlim(min(bin_edges), max(bin_edges))
    plt.show()   

def show_hog(image, orientations=8):
    from skimage.feature import hog
    from skimage import data, exposure

    f, hog_image = hog(image, orientations=orientations, pixels_per_cell=(16, 16),  cells_per_block=(1, 1), visualise=True )

    hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

    plt.figure(figsize=(10,6))
    plt.imshow(hog_image_rescaled, cmap=plt.cm.gray)
    
    #return f
    
#show_lbf(tile_of_root)
#show_lbf(tile_of_root2)
#show_lbf(tile_of_leaf)
#show_lbf(tile_of_leaf2)

# %%
show_hog(root)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
show_hog(leaf)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
show_hog(tile_of_root)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
show_hog(tile_of_root2)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
show_hog(tile_of_leaf)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
show_hog(tile_of_leaf2)
# Out:
# C:\Users\mrsir\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\feature\_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
import phasepack as pk
ret = pk.phasecongmono(tile_of_leaf)
lightroot.io.plotimg(ret[0])
lightroot.io.plotimg(ret[1])

# %%
ret = pk.phasecongmono(tile_of_root)
lightroot.io.plotimg(ret[0])
lightroot.io.plotimg(ret[1])

# %%
import numpy as np
def show_image_transform(tile):
    fourier = np.fft.fft2(tile)
    fourier = np.fft.fftshift(fourier)#cd center
    fourier=abs(fourier)
    fourier = np.log10(fourier)
    minval = np.nanmin(fourier[np.isfinite(fourier)])
    maxval = np.nanmax(fourier[np.isfinite(fourier)])
    orig_range = maxval - minval
    normed = (fourier*minval) / orig_range * 255
    lightroot.io.plotimg(normed)

# %%
show_image_transform(tile_of_leaf)
show_image_transform(tile_of_leaf2)

# %%
show_image_transform(tile_of_root)
show_image_transform(tile_of_root2)
